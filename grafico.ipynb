# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('clusters.csv')

num_clusters = data['cluster_id'].nunique()

colors = plt.cm.get_cmap('tab10', min(num_clusters, 10))
markers = ['o', 's', '^', 'P', '*', 'X', 'D', 'v', '<', '>', 'h', 'H', 'd', '|', '_', '+']

plt.figure(figsize=(10, 6))
for cluster_id in range(num_clusters):
    cluster_data = data[data['cluster_id'] == cluster_id]
    color = colors(cluster_id % 10)  
    marker = markers[cluster_id // 10 % len(markers)] 

    plt.scatter(cluster_data['x'], cluster_data['y'], 
                label=f'Cluster {cluster_id}', 
                color=color, marker=marker, 
                edgecolor='k', s=50)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Visualización de Clusters')

#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.grid(True)
plt.tight_layout()  
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_38616\295568638.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', min(num_clusters, 10))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_38616\295568638.py:17: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('|').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(cluster_data['x'], cluster_data['y'],
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_38616\295568638.py:17: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(cluster_data['x'], cluster_data['y'],
# ...
